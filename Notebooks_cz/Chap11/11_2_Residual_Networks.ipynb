# %% [markdown]
# <a href="https://colab.research.google.com/github/cz2112/hw/blob/main/Notebooks_cz/Chap11/11_2_Residual_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-osd7mhlw
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-osd7mhlw
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14664 sha256=ec2db79ce0c29fe9fc9df8f843dd861ee186b9eeb337d284061b8c04425c30c4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-uc84o0rn/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

  # TODO -- Add residual connections to this model
  def forward(self, x):
    # 1. Initial linear transformation
    h1 = self.linear1(x)

    # 2. First residual block: ReLU -> linear2, then add the input h1
    res1 = self.linear2(torch.relu(h1))
    h2 = h1 + res1

    # 3. Second residual block: ReLU -> linear3, then add the input h2
    res2 = self.linear3(torch.relu(h2))
    h3 = h2 + res2

    # 4. Final layer: ReLU -> linear4
    out = self.linear4(torch.relu(h3))
    return out

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.609084, train error 63.60,  val loss 1.683001, percent error 68.70
# Epoch     1, train loss 1.346939, train error 50.70,  val loss 1.514494, percent error 60.00
# Epoch     2, train loss 1.137976, train error 42.28,  val loss 1.372788, percent error 53.30
# Epoch     3, train loss 0.978244, train error 35.15,  val loss 1.295776, percent error 51.30
# Epoch     4, train loss 0.859372, train error 31.10,  val loss 1.229262, percent error 48.10
# Epoch     5, train loss 0.734026, train error 25.50,  val loss 1.204146, percent error 45.90
# Epoch     6, train loss 0.637202, train error 22.05,  val loss 1.135622, percent error 41.60
# Epoch     7, train loss 0.576557, train error 20.47,  val loss 1.199769, percent error 43.70
# Epoch     8, train loss 0.489074, train error 17.53,  val loss 1.143207, percent error 40.10
# Epoch     9, train loss 0.394778, train error 13.30,  val loss 1.164383, percent error 38.40
# Epoch    10, train loss 0.322619, train error 10.57,  val loss 1.135241, percent error 38.50
# Epoch    11, train loss 0.348585, train error 11.40,  val loss 1.249259, percent error 40.10
# Epoch    12, train loss 0.263107, train error 8.53,  val loss 1.223391, percent error 36.60
# Epoch    13, train loss 0.217874, train error 6.70,  val loss 1.258485, percent error 37.10
# Epoch    14, train loss 0.179368, train error 5.82,  val loss 1.273514, percent error 37.30
# Epoch    15, train loss 0.152944, train error 4.38,  val loss 1.415356, percent error 37.70
# Epoch    16, train loss 0.154372, train error 4.65,  val loss 1.414173, percent error 37.60
# Epoch    17, train loss 0.136490, train error 3.88,  val loss 1.473791, percent error 36.30
# Epoch    18, train loss 0.102225, train error 2.85,  val loss 1.449361, percent error 36.20
# Epoch    19, train loss 0.137767, train error 4.70,  val loss 1.669030, percent error 36.20
# Epoch    20, train loss 0.034227, train error 0.12,  val loss 1.425180, percent error 33.80
# Epoch    21, train loss 0.019729, train error 0.03,  val loss 1.481099, percent error 34.10
# Epoch    22, train loss 0.014699, train error 0.00,  val loss 1.500627, percent error 33.70
# Epoch    23, train loss 0.012343, train error 0.00,  val loss 1.524286, percent error 33.80
# Epoch    24, train loss 0.010915, train error 0.00,  val loss 1.549030, percent error 33.20
# Epoch    25, train loss 0.009796, train error 0.00,  val loss 1.571905, percent error 33.30
# Epoch    26, train loss 0.008887, train error 0.00,  val loss 1.589537, percent error 33.50
# Epoch    27, train loss 0.008150, train error 0.00,  val loss 1.606393, percent error 33.70
# Epoch    28, train loss 0.007561, train error 0.00,  val loss 1.630017, percent error 33.90
# Epoch    29, train loss 0.007012, train error 0.00,  val loss 1.641043, percent error 34.00
# Epoch    30, train loss 0.006583, train error 0.00,  val loss 1.651941, percent error 33.70
# Epoch    31, train loss 0.006188, train error 0.00,  val loss 1.665449, percent error 34.00
# Epoch    32, train loss 0.005844, train error 0.00,  val loss 1.680678, percent error 33.80
# Epoch    33, train loss 0.005518, train error 0.00,  val loss 1.695282, percent error 33.90
# Epoch    34, train loss 0.005244, train error 0.00,  val loss 1.705079, percent error 34.20
# Epoch    35, train loss 0.004977, train error 0.00,  val loss 1.722368, percent error 33.90
# Epoch    36, train loss 0.004753, train error 0.00,  val loss 1.730126, percent error 33.80
# Epoch    37, train loss 0.004544, train error 0.00,  val loss 1.738701, percent error 34.30
# Epoch    38, train loss 0.004361, train error 0.00,  val loss 1.748733, percent error 33.90
# Epoch    39, train loss 0.004177, train error 0.00,  val loss 1.761866, percent error 34.30
# Epoch    40, train loss 0.004083, train error 0.00,  val loss 1.764178, percent error 34.20
# Epoch    41, train loss 0.004004, train error 0.00,  val loss 1.767853, percent error 34.00
# Epoch    42, train loss 0.003928, train error 0.00,  val loss 1.774081, percent error 34.30
# Epoch    43, train loss 0.003857, train error 0.00,  val loss 1.777599, percent error 34.20
# Epoch    44, train loss 0.003787, train error 0.00,  val loss 1.781220, percent error 34.10
# Epoch    45, train loss 0.003719, train error 0.00,  val loss 1.784395, percent error 34.00
# Epoch    46, train loss 0.003655, train error 0.00,  val loss 1.788617, percent error 34.30
# Epoch    47, train loss 0.003592, train error 0.00,  val loss 1.793250, percent error 34.10
# Epoch    48, train loss 0.003532, train error 0.00,  val loss 1.795405, percent error 34.10
# Epoch    49, train loss 0.003473, train error 0.00,  val loss 1.801494, percent error 34.00
# Epoch    50, train loss 0.003417, train error 0.00,  val loss 1.802339, percent error 34.00
# Epoch    51, train loss 0.003359, train error 0.00,  val loss 1.807931, percent error 34.10
# Epoch    52, train loss 0.003308, train error 0.00,  val loss 1.812971, percent error 34.20
# Epoch    53, train loss 0.003256, train error 0.00,  val loss 1.813583, percent error 34.00
# Epoch    54, train loss 0.003204, train error 0.00,  val loss 1.820192, percent error 34.10
# Epoch    55, train loss 0.003154, train error 0.00,  val loss 1.822294, percent error 34.10
# Epoch    56, train loss 0.003107, train error 0.00,  val loss 1.826523, percent error 34.00
# Epoch    57, train loss 0.003061, train error 0.00,  val loss 1.828663, percent error 34.00
# Epoch    58, train loss 0.003017, train error 0.00,  val loss 1.831704, percent error 34.10
# Epoch    59, train loss 0.002973, train error 0.00,  val loss 1.836093, percent error 34.10
# Epoch    60, train loss 0.002950, train error 0.00,  val loss 1.837565, percent error 34.10
# Epoch    61, train loss 0.002929, train error 0.00,  val loss 1.838366, percent error 34.10
# Epoch    62, train loss 0.002909, train error 0.00,  val loss 1.840645, percent error 34.10
# Epoch    63, train loss 0.002888, train error 0.00,  val loss 1.841821, percent error 34.10
# Epoch    64, train loss 0.002868, train error 0.00,  val loss 1.843907, percent error 34.10
# Epoch    65, train loss 0.002848, train error 0.00,  val loss 1.845264, percent error 34.10
# Epoch    66, train loss 0.002829, train error 0.00,  val loss 1.846583, percent error 34.10
# Epoch    67, train loss 0.002809, train error 0.00,  val loss 1.848274, percent error 34.10
# Epoch    68, train loss 0.002790, train error 0.00,  val loss 1.850333, percent error 34.10
# Epoch    69, train loss 0.002772, train error 0.00,  val loss 1.851550, percent error 34.10
# Epoch    70, train loss 0.002753, train error 0.00,  val loss 1.853197, percent error 34.00
# Epoch    71, train loss 0.002735, train error 0.00,  val loss 1.854269, percent error 34.00
# Epoch    72, train loss 0.002717, train error 0.00,  val loss 1.855799, percent error 34.10
# Epoch    73, train loss 0.002699, train error 0.00,  val loss 1.857597, percent error 34.00
# Epoch    74, train loss 0.002681, train error 0.00,  val loss 1.858970, percent error 34.00
# Epoch    75, train loss 0.002664, train error 0.00,  val loss 1.860554, percent error 34.00
# Epoch    76, train loss 0.002647, train error 0.00,  val loss 1.862020, percent error 34.00
# Epoch    77, train loss 0.002630, train error 0.00,  val loss 1.863489, percent error 34.00
# Epoch    78, train loss 0.002613, train error 0.00,  val loss 1.865044, percent error 34.00
# Epoch    79, train loss 0.002596, train error 0.00,  val loss 1.866724, percent error 34.00
# Epoch    80, train loss 0.002588, train error 0.00,  val loss 1.867400, percent error 34.00
# Epoch    81, train loss 0.002580, train error 0.00,  val loss 1.868046, percent error 34.00
# Epoch    82, train loss 0.002572, train error 0.00,  val loss 1.868964, percent error 34.00
# Epoch    83, train loss 0.002564, train error 0.00,  val loss 1.869291, percent error 34.00
# Epoch    84, train loss 0.002556, train error 0.00,  val loss 1.869932, percent error 34.00
# Epoch    85, train loss 0.002548, train error 0.00,  val loss 1.870834, percent error 34.00
# Epoch    86, train loss 0.002540, train error 0.00,  val loss 1.871515, percent error 34.00
# Epoch    87, train loss 0.002532, train error 0.00,  val loss 1.872271, percent error 34.00
# Epoch    88, train loss 0.002524, train error 0.00,  val loss 1.873033, percent error 34.00
# Epoch    89, train loss 0.002516, train error 0.00,  val loss 1.873470, percent error 34.00
# Epoch    90, train loss 0.002509, train error 0.00,  val loss 1.874356, percent error 34.00
# Epoch    91, train loss 0.002501, train error 0.00,  val loss 1.875006, percent error 33.90
# Epoch    92, train loss 0.002493, train error 0.00,  val loss 1.875817, percent error 34.00
# Epoch    93, train loss 0.002486, train error 0.00,  val loss 1.876416, percent error 34.00
# Epoch    94, train loss 0.002478, train error 0.00,  val loss 1.877155, percent error 33.90
# Epoch    95, train loss 0.002471, train error 0.00,  val loss 1.877835, percent error 34.00
# Epoch    96, train loss 0.002464, train error 0.00,  val loss 1.878356, percent error 34.00
# Epoch    97, train loss 0.002456, train error 0.00,  val loss 1.879343, percent error 33.90
# Epoch    98, train loss 0.002449, train error 0.00,  val loss 1.879783, percent error 34.00
# Epoch    99, train loss 0.002441, train error 0.00,  val loss 1.880382, percent error 33.90

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
