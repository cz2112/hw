# %% [markdown]
# <a href="https://colab.research.google.com/github/cz2112/hw/blob/main/Notebooks/Chap11/11_2_Residual_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-gvok2dca
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-gvok2dca
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.1.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14664 sha256=20dc9bfd9833af824fd47bdc8e3689ecbf623baead88117b1f78c26213236c5e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-lbfjxvpv/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10

class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    print("Initialized ResidualNetwork model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

  # Added residual connections (Pre-activation style)
  def forward(self, x):
    # linear1 first
    h1 = self.linear1(x)

    # ReLU + linear2 in first residual block
    h2 = h1 + self.linear2(h1.relu())

    # ReLU + linear3 in second residual block
    h3 = h2 + self.linear3(h2.relu())

    # linear4 at the end (applying ReLU to the final hidden state before output)
    return self.linear4(h3.relu())

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized ResidualNetwork model with 25310 parameters
# Epoch     0, train loss 1.530472, train error 60.08,  val loss 1.603890, percent error 64.40
# Epoch     1, train loss 1.242704, train error 47.00,  val loss 1.406543, percent error 54.70
# Epoch     2, train loss 1.077616, train error 41.58,  val loss 1.309252, percent error 52.20
# Epoch     3, train loss 0.918442, train error 32.82,  val loss 1.212542, percent error 45.00
# Epoch     4, train loss 0.789896, train error 29.30,  val loss 1.167076, percent error 45.60
# Epoch     5, train loss 0.696830, train error 25.00,  val loss 1.166998, percent error 45.00
# Epoch     6, train loss 0.590036, train error 21.53,  val loss 1.091517, percent error 39.40
# Epoch     7, train loss 0.528873, train error 18.85,  val loss 1.137578, percent error 41.90
# Epoch     8, train loss 0.474347, train error 16.38,  val loss 1.189888, percent error 40.80
# Epoch     9, train loss 0.458133, train error 16.82,  val loss 1.260280, percent error 41.10
# Epoch    10, train loss 0.356750, train error 12.12,  val loss 1.152524, percent error 37.70
# Epoch    11, train loss 0.334705, train error 11.80,  val loss 1.277485, percent error 39.00
# Epoch    12, train loss 0.269073, train error 9.00,  val loss 1.182658, percent error 37.00
# Epoch    13, train loss 0.214596, train error 7.12,  val loss 1.179079, percent error 36.80
# Epoch    14, train loss 0.192509, train error 5.90,  val loss 1.299692, percent error 36.40
# Epoch    15, train loss 0.170123, train error 5.72,  val loss 1.342789, percent error 36.50
# Epoch    16, train loss 0.140119, train error 4.25,  val loss 1.362675, percent error 36.70
# Epoch    17, train loss 0.143705, train error 4.28,  val loss 1.451130, percent error 37.60
# Epoch    18, train loss 0.086849, train error 2.43,  val loss 1.356680, percent error 35.90
# Epoch    19, train loss 0.055181, train error 1.05,  val loss 1.460012, percent error 35.80
# Epoch    20, train loss 0.021548, train error 0.00,  val loss 1.381899, percent error 34.30
# Epoch    21, train loss 0.014563, train error 0.00,  val loss 1.404041, percent error 34.50
# Epoch    22, train loss 0.012225, train error 0.00,  val loss 1.427301, percent error 34.70
# Epoch    23, train loss 0.010714, train error 0.00,  val loss 1.460341, percent error 34.50
# Epoch    24, train loss 0.009422, train error 0.00,  val loss 1.463416, percent error 34.90
# Epoch    25, train loss 0.008513, train error 0.00,  val loss 1.493030, percent error 34.90
# Epoch    26, train loss 0.007817, train error 0.00,  val loss 1.510585, percent error 34.60
# Epoch    27, train loss 0.007236, train error 0.00,  val loss 1.519087, percent error 34.40
# Epoch    28, train loss 0.006774, train error 0.00,  val loss 1.533550, percent error 34.50
# Epoch    29, train loss 0.006335, train error 0.00,  val loss 1.545707, percent error 34.30
# Epoch    30, train loss 0.005941, train error 0.00,  val loss 1.564543, percent error 34.20
# Epoch    31, train loss 0.005607, train error 0.00,  val loss 1.576085, percent error 34.20
# Epoch    32, train loss 0.005349, train error 0.00,  val loss 1.588252, percent error 34.20
# Epoch    33, train loss 0.005038, train error 0.00,  val loss 1.590281, percent error 34.30
# Epoch    34, train loss 0.004812, train error 0.00,  val loss 1.606718, percent error 34.20
# Epoch    35, train loss 0.004583, train error 0.00,  val loss 1.615926, percent error 34.10
# Epoch    36, train loss 0.004385, train error 0.00,  val loss 1.621901, percent error 34.30
# Epoch    37, train loss 0.004203, train error 0.00,  val loss 1.634649, percent error 34.40
# Epoch    38, train loss 0.004043, train error 0.00,  val loss 1.640136, percent error 34.50
# Epoch    39, train loss 0.003882, train error 0.00,  val loss 1.654740, percent error 34.30
# Epoch    40, train loss 0.003798, train error 0.00,  val loss 1.655954, percent error 34.40
# Epoch    41, train loss 0.003729, train error 0.00,  val loss 1.659097, percent error 34.50
# Epoch    42, train loss 0.003662, train error 0.00,  val loss 1.663453, percent error 34.40
# Epoch    43, train loss 0.003599, train error 0.00,  val loss 1.666640, percent error 34.50
# Epoch    44, train loss 0.003534, train error 0.00,  val loss 1.669937, percent error 34.40
# Epoch    45, train loss 0.003473, train error 0.00,  val loss 1.673802, percent error 34.50
# Epoch    46, train loss 0.003415, train error 0.00,  val loss 1.678523, percent error 34.80
# Epoch    47, train loss 0.003359, train error 0.00,  val loss 1.681469, percent error 34.60
# Epoch    48, train loss 0.003305, train error 0.00,  val loss 1.683936, percent error 34.70
# Epoch    49, train loss 0.003251, train error 0.00,  val loss 1.688142, percent error 34.70
# Epoch    50, train loss 0.003201, train error 0.00,  val loss 1.692398, percent error 34.60
# Epoch    51, train loss 0.003150, train error 0.00,  val loss 1.694356, percent error 34.70
# Epoch    52, train loss 0.003102, train error 0.00,  val loss 1.697916, percent error 34.50
# Epoch    53, train loss 0.003055, train error 0.00,  val loss 1.701113, percent error 34.60
# Epoch    54, train loss 0.003009, train error 0.00,  val loss 1.704101, percent error 34.50
# Epoch    55, train loss 0.002965, train error 0.00,  val loss 1.708373, percent error 34.50
# Epoch    56, train loss 0.002922, train error 0.00,  val loss 1.710350, percent error 34.50
# Epoch    57, train loss 0.002879, train error 0.00,  val loss 1.713877, percent error 34.50
# Epoch    58, train loss 0.002839, train error 0.00,  val loss 1.716996, percent error 34.50
# Epoch    59, train loss 0.002798, train error 0.00,  val loss 1.719438, percent error 34.60
# Epoch    60, train loss 0.002778, train error 0.00,  val loss 1.721185, percent error 34.60
# Epoch    61, train loss 0.002759, train error 0.00,  val loss 1.722373, percent error 34.60
# Epoch    62, train loss 0.002741, train error 0.00,  val loss 1.723469, percent error 34.50
# Epoch    63, train loss 0.002722, train error 0.00,  val loss 1.725585, percent error 34.50
# Epoch    64, train loss 0.002703, train error 0.00,  val loss 1.727106, percent error 34.60
# Epoch    65, train loss 0.002685, train error 0.00,  val loss 1.727924, percent error 34.60
# Epoch    66, train loss 0.002667, train error 0.00,  val loss 1.729169, percent error 34.60
# Epoch    67, train loss 0.002650, train error 0.00,  val loss 1.731618, percent error 34.60
# Epoch    68, train loss 0.002632, train error 0.00,  val loss 1.732565, percent error 34.60
# Epoch    69, train loss 0.002615, train error 0.00,  val loss 1.734097, percent error 34.60
# Epoch    70, train loss 0.002598, train error 0.00,  val loss 1.735032, percent error 34.60
# Epoch    71, train loss 0.002581, train error 0.00,  val loss 1.736597, percent error 34.70
# Epoch    72, train loss 0.002565, train error 0.00,  val loss 1.737864, percent error 34.50
# Epoch    73, train loss 0.002549, train error 0.00,  val loss 1.739234, percent error 34.60
# Epoch    74, train loss 0.002532, train error 0.00,  val loss 1.740275, percent error 34.60
# Epoch    75, train loss 0.002516, train error 0.00,  val loss 1.742216, percent error 34.70
# Epoch    76, train loss 0.002500, train error 0.00,  val loss 1.743774, percent error 34.50
# Epoch    77, train loss 0.002485, train error 0.00,  val loss 1.745151, percent error 34.60
# Epoch    78, train loss 0.002470, train error 0.00,  val loss 1.746171, percent error 34.50
# Epoch    79, train loss 0.002454, train error 0.00,  val loss 1.747617, percent error 34.40
# Epoch    80, train loss 0.002446, train error 0.00,  val loss 1.748050, percent error 34.50
# Epoch    81, train loss 0.002439, train error 0.00,  val loss 1.748912, percent error 34.40
# Epoch    82, train loss 0.002431, train error 0.00,  val loss 1.749523, percent error 34.40
# Epoch    83, train loss 0.002424, train error 0.00,  val loss 1.750213, percent error 34.40
# Epoch    84, train loss 0.002417, train error 0.00,  val loss 1.750700, percent error 34.50
# Epoch    85, train loss 0.002409, train error 0.00,  val loss 1.751379, percent error 34.40
# Epoch    86, train loss 0.002402, train error 0.00,  val loss 1.752367, percent error 34.40
# Epoch    87, train loss 0.002395, train error 0.00,  val loss 1.752760, percent error 34.40
# Epoch    88, train loss 0.002388, train error 0.00,  val loss 1.753384, percent error 34.50
# Epoch    89, train loss 0.002380, train error 0.00,  val loss 1.754362, percent error 34.50
# Epoch    90, train loss 0.002373, train error 0.00,  val loss 1.754872, percent error 34.50
# Epoch    91, train loss 0.002366, train error 0.00,  val loss 1.755337, percent error 34.50
# Epoch    92, train loss 0.002359, train error 0.00,  val loss 1.756201, percent error 34.50
# Epoch    93, train loss 0.002352, train error 0.00,  val loss 1.756702, percent error 34.50
# Epoch    94, train loss 0.002345, train error 0.00,  val loss 1.757202, percent error 34.50
# Epoch    95, train loss 0.002338, train error 0.00,  val loss 1.757892, percent error 34.50
# Epoch    96, train loss 0.002331, train error 0.00,  val loss 1.758355, percent error 34.50
# Epoch    97, train loss 0.002324, train error 0.00,  val loss 1.759173, percent error 34.50
# Epoch    98, train loss 0.002318, train error 0.00,  val loss 1.760123, percent error 34.50
# Epoch    99, train loss 0.002311, train error 0.00,  val loss 1.760507, percent error 34.50

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
